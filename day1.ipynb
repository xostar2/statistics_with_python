# %%
print('raj')
# Out:
# raj

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
print("hello world")
# Out:
# hello world

# %%
a = value_a = 10 == 10
print(a)
# Out:
# True

# %%
age_child = 28

is_child = age_child < 18
print(is_child)
# Out:
# False
