# %%
# T-test

# %%
import numpy as np

np.random.seed(42)  # for reproducibility
ages = np.random.randint(18, 80, size=100)

# %%
print(ages)
# Out:
# [56 69 46 32 60 25 78 38 56 75 36 40 28 28 41 70 53 57 41 20 39 70 19 41
#  61 47 55 19 77 38 50 29 75 39 78 61 42 66 44 76 59 45 77 33 32 79 79 64
#  79 68 61 72 69 74 20 54 68 24 38 26 56 35 21 42 77 31 67 75 26 43 70 19
#  37 45 64 77 24 61 78 25 64 52 31 34 53 67 57 21 19 79 23 71 59 21 71 46
#  35 43 61 51]

# %%
mean=np.mean(ages)

# %%
mean
# Out:
# np.float64(50.27)
